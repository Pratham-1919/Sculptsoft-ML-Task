# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(r"E:\sculptsoft\27 July\train.csv\train.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
df.shape
# Out:
# (404290, 6)

# %%
small_df = df.sample(100000)
small_df.head()
# Out:
#             id    qid1    qid2  \
# 263712  263712  380302  380303
# 398899  398899  532142  532143
# 244306  244306   25184  118171
# 273072  273072   63784  125452
# 16983    16983    2323    1934
#
#                                                 question1  \
# 263712                 Would a girl lie about loving you?
# 398899  What is the best strategy to launch a niche ec...
# 244306  What is the most upvoted answer of all time on...
# 273072      What's the difference between "for" and "to"?
# 16983                How can I improve my spoken English?
#
#                                                 question2  is_duplicate
# 263712  If you are dreaming about a girl, are you in l...             0
# 398899  What's it like to work at AMC Entertainment fo...             0
# 244306               What is a top voted answer on Quora?             1
# 273072         What is the difference between to and for?             1
# ...

# %%
small_df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
question_df = small_df[["question1", "question2"]]
question_df.head()
# Out:
#                                                 question1  \
# 263712                 Would a girl lie about loving you?
# 398899  What is the best strategy to launch a niche ec...
# 244306  What is the most upvoted answer of all time on...
# 273072      What's the difference between "for" and "to"?
# 16983                How can I improve my spoken English?
#
#                                                 question2
# 263712  If you are dreaming about a girl, are you in l...
# 398899  What's it like to work at AMC Entertainment fo...
# 244306               What is a top voted answer on Quora?
# 273072         What is the difference between to and for?
# 16983                       How can I understand english?

# %%
correct_questions = (
    question_df["question1"].tolist() + question_df["question2"].tolist()
)

# %%
print(f"Total items in list: {len(correct_questions)}\n")
print("First 4 items (Question 1s):", correct_questions[:4])
print("Last 4 items (Question 2s):", correct_questions[4:])
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
